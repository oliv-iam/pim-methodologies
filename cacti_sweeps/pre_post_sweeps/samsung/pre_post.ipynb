# %%
import matplotlib.pyplot as plt

# %%
xaxis = ['[4]', 't_RCD (ns)', 't_RAS (ns)', 't_RC (ns)', 't_CAS (ns)', 't_RP (ns)', 't_RRD (ns)', 'P_ACT (nJ)', 'P_RD (nJ)', 'P_WR (nJ)', '[3]', '[1]', '[2]']
one = 'TSV latency overhead (ns)'
two = 'TSV energy overhead per access (nJ)'
three = 'Precharge energy (nJ)'
four = 'IO Area (sq.mm)'
y_basic = [float('inf'), 1.14548e+107, 1.14548e+107, 1.14548e+107, 2.29096e+107, 1.14548e+107, 1.14548e+107, 6.14115e+54, 6.14115e+54, 6.14115e+54, 6.14115e+54, 1.14548e+107, 6.14115e+54]
y_mod = [2.90152, 7.84292, 29.194, 49.1003, 16.9298, 20.648, 4.06969, 1.81143, 1.11818, 1.1182, 1.67972, 0.741733, 0.0481619]

# %%
colors = ['#6b76b1', '#bcbddb', '#fee609', '#fcf49f', '#e6e7e8']
plt.rcParams.update({'font.size': 15})

# combined
f, ax = plt.subplots()
ax.scatter(xaxis, y_basic, color=colors[0], s=150, label='basic CACTI')
ax.scatter(xaxis, y_mod, color=colors[1], s=150, label='modified CACTI')
ax.legend()
ax.set_ylabel('output value')
ax.set_xlabel('corrected CACTI metrics')
ax.set_yticks([0, 0.5e107, 1e107, 1.5e107, 2e107])
ax.set_yticklabels([0, 5e106, 1e107, 1.5e107, 2e107])
f.set_size_inches(6, 4)
ax.tick_params(axis='x', labelrotation=-90)
plt.show()
plt.close()

# post modification
plt.scatter(xaxis, y_mod, color=colors[1], s=150)
plt.tick_params(axis='x', labelrotation=-90)
